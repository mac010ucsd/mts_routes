# %%
import networkx as nx
import osmnx as ox

ox.__version__
# Out:
# '2.0.3'

# %%
# G = ox.graph.graph_from_place("San Diego, California, USA", network_type="walk")
G = ox.graph.graph_from_point(ox.geocoder.geocode("UCSD"), 1000, network_type="walk")

# %%
fig, ax = ox.plot.plot_graph(G, figsize=(10,10))

# %%
G1 = ox.routing.add_edge_speeds(G)
G1 = ox.routing.add_edge_travel_times(G1)

# %%
# nx.get_edge_attributes(G1)

#G1.edges(data=True)

# %%
ec = ox.plot.get_edge_colors_by_attr(G, "travel_time", cmap="inferno")
fig, ax = ox.plot.plot_graph(G1, edge_color=ec, edge_linewidth=2, node_size=0)

# %%
G2 = ox.convert.to_undirected(G1)

# %%
data_flow = nx.current_flow_closeness_centrality(G2, weight="travel_time")

# %%
# nx.Graph(data_flow)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File /opt/homebrew/lib/python3.11/site-packages/networkx/convert.py:97, in to_networkx_graph(data, create_using, multigraph_input)
#      96 try:
# ---> 97     return from_dict_of_dicts(
#      98         data, create_using=create_using, multigraph_input=multigraph_input
#      99     )
#     100 except Exception as err1:
#
# File <class 'networkx.utils.decorators.argmap'> compilation 14:3, in argmap_from_dict_of_dicts_11(d, create_using, multigraph_input, backend, **backend_kwargs)
#       2 import collections
# ----> 3 import gzip
#       4 import inspect
#
# File /opt/homebrew/lib/python3.11/site-packages/networkx/utils/backends.py:967, in _dispatchable.__call__(self, backend, *args, **kwargs)
#     966         raise ImportError(f"'{backend}' backend is not installed")
# --> 967     return self.orig_func(*args, **kwargs)
#     969 # Use `backend_name` in this function instead of `backend`.
#     970 # This is purely for aesthetics and to make it easier to search for this
#     971 # variable since "backend" is used in many comments and log/error messages.
#
# File /opt/homebrew/lib/python3.11/site-packages/networkx/convert.py:454, in from_dict_of_dicts(d, create_using, multigraph_input)
#     453     else:
# --> 454         G.add_edges_from(
#     455             ((u, v, data) for u, nbrs in d.items() for v, data in nbrs.items())
#     456         )
#     457 return G
#
# File /opt/homebrew/lib/python3.11/site-packages/networkx/classes/graph.py:1030, in Graph.add_edges_from(self, ebunch_to_add, **attr)
#     976 """Add all the edges in ebunch_to_add.
#     977
#     978 Parameters
#    (...)   1028 >>> G.add_edges_from(list((5, n) for n in G.nodes))
#    1029 """
# -> 1030 for e in ebunch_to_add:
#    1031     ne = len(e)
#
# File /opt/homebrew/lib/python3.11/site-packages/networkx/convert.py:455, in <genexpr>(.0)
#     453     else:
#     454         G.add_edges_from(
# --> 455             ((u, v, data) for u, nbrs in d.items() for v, data in nbrs.items())
#     456         )
#     457 return G
#
# AttributeError: 'float' object has no attribute 'items'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# File /opt/homebrew/lib/python3.11/site-packages/networkx/convert.py:106, in to_networkx_graph(data, create_using, multigraph_input)
#     105 try:
# --> 106     return from_dict_of_lists(data, create_using=create_using)
#     107 except Exception as err2:
#
# File /opt/homebrew/lib/python3.11/site-packages/networkx/utils/decorators.py:788, in argmap.__call__.<locals>.func(_argmap__wrapper, *args, **kwargs)
#     787 def func(*args, __wrapper=None, **kwargs):
# --> 788     return argmap._lazy_compile(__wrapper)(*args, **kwargs)
#
# File <class 'networkx.utils.decorators.argmap'> compilation 61:3, in argmap_from_dict_of_lists_58(d, create_using, backend, **backend_kwargs)
#       2 import collections
# ----> 3 import gzip
#       4 import inspect
#
# File /opt/homebrew/lib/python3.11/site-packages/networkx/utils/backends.py:967, in _dispatchable.__call__(self, backend, *args, **kwargs)
#     966         raise ImportError(f"'{backend}' backend is not installed")
# --> 967     return self.orig_func(*args, **kwargs)
#     969 # Use `backend_name` in this function instead of `backend`.
#     970 # This is purely for aesthetics and to make it easier to search for this
#     971 # variable since "backend" is used in many comments and log/error messages.
#
# File /opt/homebrew/lib/python3.11/site-packages/networkx/convert.py:248, in from_dict_of_lists(d, create_using)
#     247 else:
# --> 248     G.add_edges_from(
#     249         ((node, nbr) for node, nbrlist in d.items() for nbr in nbrlist)
#     250     )
#     251 return G
#
# File /opt/homebrew/lib/python3.11/site-packages/networkx/classes/graph.py:1030, in Graph.add_edges_from(self, ebunch_to_add, **attr)
#     976 """Add all the edges in ebunch_to_add.
#     977
#     978 Parameters
#    (...)   1028 >>> G.add_edges_from(list((5, n) for n in G.nodes))
#    1029 """
# -> 1030 for e in ebunch_to_add:
#    1031     ne = len(e)
#
# File /opt/homebrew/lib/python3.11/site-packages/networkx/convert.py:249, in <genexpr>(.0)
#     247 else:
#     248     G.add_edges_from(
# --> 249         ((node, nbr) for node, nbrlist in d.items() for nbr in nbrlist)
#     250     )
#     251 return G
#
# TypeError: 'float' object is not iterable
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 nx.Graph(data_flow)
#
# File /opt/homebrew/lib/python3.11/site-packages/networkx/classes/graph.py:378, in Graph.__init__(self, incoming_graph_data, **attr)
#     376 # attempt to load graph with data
#     377 if incoming_graph_data is not None:
# --> 378     convert.to_networkx_graph(incoming_graph_data, create_using=self)
#     379 # load graph attributes (must be after convert)
#     380 self.graph.update(attr)
#
# File /opt/homebrew/lib/python3.11/site-packages/networkx/convert.py:108, in to_networkx_graph(data, create_using, multigraph_input)
#     106             return from_dict_of_lists(data, create_using=create_using)
#     107         except Exception as err2:
# --> 108             raise TypeError("Input is not known type.") from err2
#     110 # edgelists
#     111 if isinstance(data, list | tuple | nx.reportviews.EdgeViewABC | Iterator):
#
# TypeError: Input is not known type.

# %%
nx.set_node_attributes(G2, data_flow, name="flow")
# G3

# %%
nc = ox.plot.get_node_colors_by_attr(G, "flow", cmap="inferno")
fig, ax = ox.plot.plot_graph(G1, node_color=ec)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 fig, ax = ox.plot.plot_graph(G3, figsize=(10,10))
#
# File /opt/homebrew/lib/python3.11/site-packages/osmnx/plot.py:257, in plot_graph(G, ax, figsize, bgcolor, node_color, node_size, node_alpha, node_edgecolor, node_zorder, edge_color, edge_linewidth, edge_alpha, bbox, show, close, save, filepath, dpi)
#     253 fig, ax = _get_fig_ax(ax=ax, figsize=figsize, bgcolor=bgcolor, polar=False)
#     255 if max_edge_lw > 0:
#     256     # plot the edges' geometries
# --> 257     gdf_edges = convert.graph_to_gdfs(G, nodes=False)["geometry"]
#     258     ax = gdf_edges.plot(ax=ax, color=edge_color, lw=edge_linewidth, alpha=edge_alpha, zorder=1)
#     260 if max_node_size > 0:
#     261     # scatter plot the nodes' x/y coordinates
#
# File /opt/homebrew/lib/python3.11/site-packages/osmnx/convert.py:146, in graph_to_gdfs(G, nodes, edges, node_geometry, fill_edge_geometry)
#     113 def graph_to_gdfs(
#     114     G: nx.MultiGraph | nx.MultiDiGraph,
#     115     *,
#    (...)    119     fill_edge_geometry: bool = True,
#     120 ) -> gpd.GeoDataFrame | tuple[gpd.GeoDataFrame, gpd.GeoDataFrame]:
#     121     """
#     122     Convert a MultiGraph or MultiDiGraph to node and/or edge GeoDataFrames.
#     123
#    (...)    144         `(u, v, key)` following normal MultiGraph/MultiDiGraph structure.
#     145     """
# --> 146     crs = G.graph["crs"]
#     148     if nodes:
#     149         if len(G.nodes) == 0:  # pragma: no cover
#
# AttributeError: 'NoneType' object has no attribute 'graph'
